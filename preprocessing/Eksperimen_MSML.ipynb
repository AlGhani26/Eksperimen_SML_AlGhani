# %% [markdown]
# # **1. Perkenalan Dataset**

# %% [markdown]
# Dataset yang digunakan dalam penelitian ini berjudul "Extrovert vs. Introvert Behavior Data", yang berisi informasi mengenai perilaku dan kecenderungan sosial individu berdasarkan ciri kepribadian ekstrovert dan introvert. Dataset ini bertujuan untuk membantu analisis terhadap bagaimana seseorang berinteraksi dengan lingkungan sosialnya, serta memberikan wawasan mengenai pola-pola umum yang membedakan dua tipe kepribadian tersebut.
#
# Dataset ini terdiri dari 2.900 baris data dengan 8 fitur, yang mencakup aspek-aspek perilaku seperti frekuensi menghadiri acara sosial, kebiasaan memposting di media sosial, serta jumlah waktu yang dihabiskan sendirian. Salah satu kolom merupakan variabel target, yaitu tipe kepribadian: Extrovert atau Introvert.
#
# Adapun fitur-fitur dalam dataset ini meliputi:
# - `Time_spent_Alone:` Jumlah jam yang dihabiskan sendirian setiap hari (rentang 0–11 jam).
# - `Stage_fear:` Apakah individu memiliki rasa takut tampil di depan umum (Ya/Tidak).
# - `Social_event_attendance:` Frekuensi individu menghadiri acara sosial (rentang 0–10).
# - `Going_outside:` Seberapa sering individu keluar rumah dalam seminggu (rentang 0–7).
# - `Drained_after_socializing`: Apakah individu merasa lelah setelah bersosialisasi (Ya/Tidak).
# - `Friends_circle_size:` Jumlah teman dekat yang dimiliki (rentang 0–15).
# - `Post_frequency:` Frekuensi memposting di media sosial (rentang 0–10).
# - `Personality:` Tipe kepribadian individu, yaitu Extrovert atau Introvert.
#
# Secara umum, dataset ini sangat berguna dalam berbagai bidang, seperti psikologi, sosiologi, dan machine learning, khususnya dalam pengembangan model prediksi kepribadian atau pemahaman perilaku sosial.
#
# Dataset ini dapat diunduh secara gratis melalui platform Kaggle pada tautan berikut:
# 🔗 https://www.kaggle.com/datasets/rakeshkapilavai/extrovert-vs-introvert-behavior-data

# %% [markdown]
# # **2. Import Library**

# %% [markdown]
# Pada tahap ini, Anda perlu mengimpor beberapa pustaka (library) Python yang dibutuhkan untuk analisis data dan pembangunan model machine learning atau deep learning.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# %% [markdown]
# # **3. Memuat Dataset**

# %% [markdown]
# Pada tahap ini, Anda perlu memuat dataset ke dalam notebook. Jika dataset dalam format CSV, Anda bisa menggunakan pustaka pandas untuk membacanya. Pastikan untuk mengecek beberapa baris awal dataset untuk memahami strukturnya dan memastikan data telah dimuat dengan benar.
#
# Jika dataset berada di Google Drive, pastikan Anda menghubungkan Google Drive ke Colab terlebih dahulu. Setelah dataset berhasil dimuat, langkah berikutnya adalah memeriksa kesesuaian data dan siap untuk dianalisis lebih lanjut.
#
# Jika dataset berupa unstructured data, silakan sesuaikan dengan format seperti kelas Machine Learning Pengembangan atau Machine Learning Terapan

# %%
df = pd.read_csv('D:\Document\PROYEK\Dicoding\MSML\Eksperimen_SML_AlGhani\personality_dataset.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\algha\AppData\Local\Temp\ipykernel_22780\3818833059.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('D:\Document\PROYEK\Dicoding\MSML\Eksperimen_SML_AlGhani\personality_dataset.csv')

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**
#
# Pada tahap ini, Anda akan melakukan **Exploratory Data Analysis (EDA)** untuk memahami karakteristik dataset.
#
# Tujuan dari EDA adalah untuk memperoleh wawasan awal yang mendalam mengenai data dan menentukan langkah selanjutnya dalam analisis atau pemodelan.

# %% [markdown]
# Melihat data head sampel

# %%
df.head()
# Out:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         No                      4.0            6.0
# 1               9.0        Yes                      0.0            0.0
# 2               9.0        Yes                      1.0            2.0
# 3               0.0         No                      6.0            7.0
# 4               3.0         No                      9.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 13.0             5.0   Extrovert
# 1                       Yes                  0.0             3.0   Introvert
# 2                       Yes                  5.0             2.0   Introvert
# 3                        No                 14.0             8.0   Extrovert
# 4                        No                  8.0             5.0   Extrovert

# %% [markdown]
# Melihat jumlah baris dan kolom dataset

# %%
df.shape
# Out:
# (2900, 8)

# %% [markdown]
# Menampilkan statistik deskriptif dataset (numeric only)

# %%
df.describe()
# Out:
#        Time_spent_Alone  Social_event_attendance  Going_outside  \
# count       2837.000000              2838.000000    2834.000000
# mean           4.505816                 3.963354       3.000000
# std            3.479192                 2.903827       2.247327
# min            0.000000                 0.000000       0.000000
# 25%            2.000000                 2.000000       1.000000
# 50%            4.000000                 3.000000       3.000000
# 75%            8.000000                 6.000000       5.000000
# max           11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count          2823.000000     2835.000000
# mean              6.268863        3.564727
# std               4.289693        2.926582
# min               0.000000        0.000000
# 25%               3.000000        1.000000
# 50%               5.000000        3.000000
# 75%              10.000000        6.000000
# ...

# %% [markdown]
# Menampilkan statistik deskriptif dataset (seluruh kolom)

# %%
df.describe(include='all')
# Out:
#         Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# count        2837.000000       2827              2838.000000    2834.000000
# unique               NaN          2                      NaN            NaN
# top                  NaN         No                      NaN            NaN
# freq                 NaN       1417                      NaN            NaN
# mean            4.505816        NaN                 3.963354       3.000000
# std             3.479192        NaN                 2.903827       2.247327
# min             0.000000        NaN                 0.000000       0.000000
# 25%             2.000000        NaN                 2.000000       1.000000
# 50%             4.000000        NaN                 3.000000       3.000000
# 75%             8.000000        NaN                 6.000000       5.000000
# max            11.000000        NaN                10.000000       7.000000
#
# ...

# %% [markdown]
# Cek Missing Values

# %%
print(df.info())
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time_spent_Alone           2837 non-null   float64
#  1   Stage_fear                 2827 non-null   object
#  2   Social_event_attendance    2838 non-null   float64
#  3   Going_outside              2834 non-null   float64
#  4   Drained_after_socializing  2848 non-null   object
#  5   Friends_circle_size        2823 non-null   float64
#  6   Post_frequency             2835 non-null   float64
#  7   Personality                2900 non-null   object
# dtypes: float64(5), object(3)
# memory usage: 181.4+ KB
# None
#
# Missing values per column:
# Time_spent_Alone             63
# Stage_fear                   73
# Social_event_attendance      62
# Going_outside                66
# Drained_after_socializing    52
# Friends_circle_size          77
# ...

# %% [markdown]
# Hasil Analisis Sementara :
# - Terdapat beberapa data yang tidak lengkap pada semua kolom
# - Nilai mean dan median pada fitur numerik tidak terlalu jauh, menandakan distribusi cukup normal.
# - Fitur kategorikal seperti Stage_fear dan Drained_after_socializing menunjukkan keragaman respon yang cukup untuk membedakan karakteristik kepribadian.
# - Variabel target Personality cukup seimbang, sehingga cocok untuk model klasifikasi tanpa perlu penanganan berat terhadap imbalance data.

# %% [markdown]
# Analisis Univariate

# %% [markdown]
# Fitur Numeric

# %%
num_cols = ['Time_spent_Alone', 'Social_event_attendance', 'Going_outside',
            'Friends_circle_size', 'Post_frequency']

plt.figure(figsize=(15, 10))
for i, col in enumerate(num_cols):
    plt.subplot(2, 3, i+1)
    sns.histplot(df[col], kde=True, bins=20, color='skyblue')
    plt.title(f'Distribusi {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# Fitur Kategorikal

# %%
cat_cols = ['Stage_fear', 'Drained_after_socializing', 'Personality']

plt.figure(figsize=(15, 4))
for i, col in enumerate(cat_cols):
    plt.subplot(1, 3, i+1)
    sns.countplot(x=col, data=df, palette='Set2')
    plt.title(f'Distribusi {col}')
    plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\algha\AppData\Local\Temp\ipykernel_22780\2883380152.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='Set2')
# C:\Users\algha\AppData\Local\Temp\ipykernel_22780\2883380152.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='Set2')
# C:\Users\algha\AppData\Local\Temp\ipykernel_22780\2883380152.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='Set2')

# %% [markdown]
# Analisis Multivariate

# %% [markdown]
# Korelasi Antar Fitur Numerik

# %%
plt.figure(figsize=(10, 6))
corr = df[num_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matriks Korelasi')
plt.show()

# %% [markdown]
# Analisis Fitur Numerik dengan Target

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(num_cols):
    plt.subplot(2, 3, i+1)
    sns.boxplot(x='Personality', y=col, data=df, palette='pastel')
    plt.title(f'{col} berdasarkan Personality')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\algha\AppData\Local\Temp\ipykernel_22780\925351668.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Personality', y=col, data=df, palette='pastel')
# C:\Users\algha\AppData\Local\Temp\ipykernel_22780\925351668.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Personality', y=col, data=df, palette='pastel')
# C:\Users\algha\AppData\Local\Temp\ipykernel_22780\925351668.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Personality', y=col, data=df, palette='pastel')
# ...

# %%
sns.pairplot(df[num_cols + ['Personality']], hue='Personality', palette='husl')
plt.show()

# %% [markdown]
# Analisis Fitur Kategorikal dengan Target

# %%
for col in ['Stage_fear', 'Drained_after_socializing']:
    ct = pd.crosstab(df[col], df['Personality'], normalize='index') * 100
    ct.plot(kind='bar', stacked=True, figsize=(6, 4), colormap='Set3')
    plt.ylabel('Persentase (%)')
    plt.title(f'Distribusi {col} terhadap Personality')
    plt.legend(title='Personality')
    plt.show()

# %% [markdown]
# # **5. Data Preprocessing**

# %% [markdown]
# Pada tahap ini, data preprocessing adalah langkah penting untuk memastikan kualitas data sebelum digunakan dalam model machine learning.
#
# Jika Anda menggunakan data teks, data mentah sering kali mengandung nilai kosong, duplikasi, atau rentang nilai yang tidak konsisten, yang dapat memengaruhi kinerja model. Oleh karena itu, proses ini bertujuan untuk membersihkan dan mempersiapkan data agar analisis berjalan optimal.
#
# Berikut adalah tahapan-tahapan yang bisa dilakukan, tetapi **tidak terbatas** pada:
# 1. Menghapus atau Menangani Data Kosong (Missing Values)
# 2. Menghapus Data Duplikat
# 3. Normalisasi atau Standarisasi Fitur
# 4. Deteksi dan Penanganan Outlier
# 5. Encoding Data Kategorikal
# 6. Binning (Pengelompokan Data)
#
# Cukup sesuaikan dengan karakteristik data yang kamu gunakan yah. Khususnya ketika kami menggunakan data tidak terstruktur.

# %%
# 1. Menghapus data kosong (karena jumlahnya kecil)
df_clean = df.dropna()
print("Ukuran data setelah hapus missing values:", df_clean.shape)
# Out:
# Ukuran data setelah hapus missing values: (2477, 8)

# %%
# 2. Menghapus data duplikat (jika ada)
df_clean = df_clean.drop_duplicates()
print("Ukuran data setelah hapus duplikat:", df_clean.shape)
# Out:
# Ukuran data setelah hapus duplikat: (2098, 8)

# %%
# 3. Normalisasi fitur numerik (0–1)
num_cols = ['Time_spent_Alone', 'Social_event_attendance', 'Going_outside',
            'Friends_circle_size', 'Post_frequency']

scaler = MinMaxScaler()
df_clean[num_cols] = scaler.fit_transform(df_clean[num_cols])

# %%
# 4. Encoding data kategorikal (Label Encoding)
cat_cols = ['Stage_fear', 'Drained_after_socializing', 'Personality']
label_encoders = {}

for col in cat_cols:
    le = LabelEncoder()
    df_clean[col] = le.fit_transform(df_clean[col])
    label_encoders[col] = le  # simpan encoder jika ingin inverse_transform nanti

# %%
# Lihat hasil akhir
print("\nData setelah preprocessing:")
print(df_clean.head())
# Out:
# Data setelah preprocessing:
#    Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0          0.363636           0                      0.4       0.857143
# 1          0.818182           1                      0.0       0.000000
# 2          0.818182           1                      0.1       0.285714
# 3          0.000000           0                      0.6       1.000000
# 4          0.272727           0                      0.9       0.571429
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency  Personality
# 0                          0             0.866667             0.5            0
# 1                          1             0.000000             0.3            1
# 2                          1             0.333333             0.2            1
# 3                          0             0.933333             0.8            0
# 4                          0             0.533333             0.5            0

# %%
# Simpan hasil preprocessing ke file CSV
df_clean.to_csv('personality_preprocessing_dataset.csv', index=False)
print("Data berhasil disimpan sebagai 'personality_preprocessing_dataset.csv'")
# Out:
# Data berhasil disimpan sebagai 'personality_preprocessing_dataset.csv'
